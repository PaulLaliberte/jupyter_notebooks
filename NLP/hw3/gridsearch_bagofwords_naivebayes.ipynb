# %% [markdown]
# # Grid Search - Naive Bayes
#
# >**Note:** You will need more memory than on a standard laptop, and multiple cpus is ideal.

# %%
import pandas as pd
import numpy as np

from nltk.stem import SnowballStemmer

from sklearn.naive_bayes import MultinomialNB

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_pickle('../../data/train.pkl')
df
# Out:
#           id                                           sentence  label
# 0    ID-1210  Went to this hotel when visiting nearby nation...      1
# 1    ID-1036  Over the holidays, we stayed at the Westin in ...      1
# 2    ID-1262  Beautiful resort with excellent views of the o...      1
# 3    ID-1162  This is a fantastic botique hotel in Portland,...      1
# 4    ID-1174  Headed up to Massachusetts for the New England...      1
# 5    ID-1266  The Beachcomber Resort & Villas is what makes ...      1
# 6    ID-1274  Absolutely a great hotel for families! The roo...      1
# 7    ID-1146  We had an incredible stay at The XV Beacon. It...      1
# 8    ID-1074  The Holiday Inn near the stadium in Philly was...      1
# 9    ID-1064  A night at the Hotel Roanoke is a charming exp...      1
# 10   ID-1246  The San Francisco Marriot at Union Square is a...      1
# 11   ID-1046  This place is a piece of heaven on earth. As w...      1
# 12   ID-1160  Howard Johnson hotels are the best value for y...      1
# 13   ID-1230  This hotel was absolutely beautiful as soon as...      1
# 14   ID-1194  My wife, two-year old son and I stayed at La Q...      1
# 15   ID-1134  My husband and I were recently on a business t...      1
# 16   ID-1202  Staying at the Bon Aire on St. Pete Beach is b...      1
# 17   ID-1112  I stay at Great Wolf Lodge at least 3 times a ...      1
# 18   ID-1234  The Kalahari is a great place to take your kid...      1
# 19   ID-1182  I stayed here several times while visiting fri...      1
# 20   ID-1098  The Westin in Virginia Beach is by far my favo...      1
# 21   ID-1120  We stayed at The Oread in the Fall for a work ...      1
# 22   ID-1228  I had a wonderful, relaxed stay at the Huntley...      1
# 23   ID-1106  I took a trip to New York for a couple of days...      1
# 24   ID-1258  I stayed at this hotel with my family last sum...      1
# 25   ID-1116  This the best hotel for the money that I paid ...      1
# 26   ID-1102  The hotel was enjoyable because the price was ...      1
# 27   ID-1212  I've stayed at this hotel several times and al...      1
# 28   ID-1224  Hampton Inn and Suites in Lakeland Florida was...      1
# 29   ID-1270  This hotel and resort is wonderful for family ...      1
# ..       ...                                                ...    ...
# 159  ID-0909  I booked a weekend at Terranea for my birthday...      0
# 160  ID-0901  The Inn at El Gaucho in Seattle sounded like a...      0
# 161  ID-0841  I stayed at the Quality Inn in Hinesville Ga, ...      0
# 162  ID-1011  I stayed at this days inn hotel for 5 days and...      0
# 163  ID-0947  I stayed for business for 4 nights. I requeste...      0
# 164  ID-1013  I called weeks in advance to reserve a room, a...      0
# 165  ID-0999  I had booked a one week stay at the St. August...      0
# 166  ID-1033  My son and I made a spur of the moment decisio...      0
# 167  ID-0961  When I booked my stay, I was not informed that...      0
# 168  ID-1023  I really didn't like how cheap this motel was....      0
# 169  ID-0835  I went to Syracuse last winter to watch my tea...      0
# 170  ID-0893  This Red Roof Inn in North Charleston, South C...      0
# 171  ID-0817  The hotel has very thin walls and ceiling so y...      0
# 172  ID-0803  On my way home from a trip with my family, the...      0
# 173  ID-0811  The Rio hotel is the absolute worst hotel I've...      0
# 174  ID-0987  The Ao Chalong Hotel in Phuket, Thailand was a...      0
# 175  ID-0929  When I visited this hotel, I thought everythin...      0
# 176  ID-0801  We were visiting Salem and only stayed one nig...      0
# 177  ID-0923  The inclusion of insects in your hotel room is...      0
# 178  ID-0871  This was our first and only stay at the Ambass...      0
# 179  ID-0795  This hotel was mediocre. It did not live up to...      0
# 180  ID-0899  I didn't enjoy my experience in this hotel bec...      0
# 181  ID-0969  Me and my family stayed here during the 4th of...      0
# 182  ID-0849  The Circus Circus hotel in Reno, Nevada is not...      0
# 183  ID-0967  We didn't feel at home at the Crowne Plaza nea...      0
# 184  ID-0981  I am a business traveler that often had to sta...      0
# 185  ID-0799  I recently stayed at the Astor Crown Plaza in ...      0
# 186  ID-0957  I booked this hotel last week while visiting P...      0
# 187  ID-0809  We arrived at the hotel about 5 pm. First of a...      0
# 188  ID-1007  I recently stayed at the Aliante Station Casin...      0
#
# [189 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df['sentence'].values, df['label'].values)

# %%
sb_stemmer = SnowballStemmer(language='english')

class Snowball_CountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(Snowball_CountVectorizer, self).build_analyzer()
        return lambda doc:([sb_stemmer.stem(word) for word in analyzer(doc)])

# %%
#pipline
pipeline = Pipeline([
        ('features', FeatureUnion([
            ('counts', Snowball_CountVectorizer())
        ])),
        ('classifier', MultinomialNB())
    ])

# %%
parameters = {
              'classifier__alpha': [.3, .4, .5, .6, .7],
              'features__counts__min_df' : [1, 2, 3, 5],
              'features__counts__max_df' : [10, 20, 50],
              'features__counts__stop_words' : ['english', None],
              'features__counts__ngram_range' :[(1,1), (1,2), (2,2), (1,3), (2,3)],
              'features__counts__lowercase' : [True, False]
             }

# %%
clf = GridSearchCV(pipeline, parameters, cv=5)

# %%
clf.fit(X_train, y_train)

# %%
clf.best_estimator_.get_params()

# %%
clf.cv_results_['mean_test_score']

# %%
with open('best_params.txt', 'w') as file:
     file.write(str(clf.best_estimator_.get_params()))
