# %% [markdown]
# # Task 1: Model Fitting and Testing
# ***
#
# We split our dataframe into train and test sets, and then fit the model (svm - linear kernel) and run predictions.

# %%
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.util import ngrams

from sklearn.linear_model import SGDClassifier

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.base import BaseEstimator, TransformerMixin

from sklearn.pipeline import Pipeline, FeatureUnion

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('dataframe_pickles/f_codes_extended_1000.csv', encoding='utf-8-sig')
X = df['2'].values[1:]    #inputs - abstract
y = df['5'].values[1:]    #outputs - 1: F    0: ~F

X_train, X_test, y_train, y_test = train_test_split(X,y)

# %% [markdown]
# >We can create our own features to fit to the model.

# %%
#keywords associated with 'F' JEL codes
kw = []
max_length = 1
for line in open('f_code_keyword.txt'):
    words = line.split(',')
    for phrase in words:
        phrase = phrase.split()
        list_of_words = []
        for word in phrase:
            list_of_words.append(re.sub(r"[^\w\-]+", '', word))
            
        if len(list_of_words) > 0:
            w = list_of_words[0].lower()
    
            if len(list_of_words) > 1:
                for i in list_of_words[1:]:
                    w = w + ' ' + i.lower()
                    
                if len(list_of_words) > max_length:
                    max_length = len(list_of_words)
                    
            
                kw.append(w) 
            else:
                kw.append(w)
        else:
            pass

kw = list(set(kw))
kw
# Out:
# ['product differentiation',
#  'trade imbalance',
#  'exchange rate',
#  'unemployment',
#  'mnc',
#  'fob',
#  'dual exchange rate',
#  'in kind aid',
#  'crisis',
#  'economic integration',
#  'special drawing rights',
#  'monetary unions',
#  'cemac',
#  'international',
#  'borrowing',
#  'employment',
#  'official development assistance',
#  'consumer',
#  'international political economy',
#  'political economy',
#  'mercosur',
#  'macroeconomic policy coordination',
#  'afta',
#  'eurobonds',
#  'out migration',
#  'export',
#  'policy making',
#  'j curve',
#  'labor market',
#  'simulation',
#  'sterling area',
#  'commercial policy',
#  'financial globalization',
#  'development bank',
#  'foreign debt',
#  'international lending',
#  'wto',
#  'country risk',
#  'small open economy',
#  'international trade',
#  'joint venture',
#  'peg',
#  'import competing',
#  'fixed exchange rate',
#  'behavior',
#  'risk premia',
#  'currency risk',
#  'factor price equalization',
#  'international bank for reconstruction and development',
#  'international monetary',
#  'oecd',
#  'debt crisis',
#  'international trade agreements',
#  'purchasing power',
#  'mne',
#  'emu',
#  'international agreement',
#  'infant industry',
#  'eurocurrencies',
#  'international norms',
#  'nationalization',
#  'alien',
#  'international debt forecasting',
#  'convertibility',
#  'informal exchange rate',
#  'international trade organizations',
#  'migration',
#  'comparative advantage',
#  'border',
#  'asean',
#  'financial development',
#  'currencies',
#  'expatriate',
#  'financial liberalization',
#  'international relations',
#  'debtor nation',
#  'free trade area',
#  'international investment',
#  'new trade theory',
#  'foreign',
#  'globalization',
#  'nato',
#  'convention',
#  'growth',
#  'commodity agreements',
#  'cash aid',
#  'customs',
#  'devaluation',
#  'european union',
#  'dual',
#  'optimum integration area',
#  'national security',
#  'tnc',
#  'banking',
#  'duty',
#  'trade simulation',
#  'currency substitution',
#  'money price',
#  'forward rate',
#  'factor price',
#  'international public goods',
#  'international outsourcing',
#  'religious organization',
#  'nationalism',
#  'import',
#  'eurocentricism',
#  'dollarization',
#  'intra industry',
#  'customs union',
#  'developing countries',
#  'environment',
#  'union',
#  'exports',
#  'international business fluctuation',
#  'economic',
#  'recipient',
#  'monopolistic competition',
#  'bretton woods',
#  'imf',
#  'smoot hawley',
#  'offshore',
#  'current account forecasting',
#  'trade agreements',
#  'leading indicators',
#  'nontradable',
#  'international trade forecasting',
#  'price',
#  'european monetary union',
#  'international comparison of income',
#  'trade forecast',
#  'fragmentation',
#  'heterogeneous firms',
#  'trade theoretic',
#  'silver standard',
#  'ec',
#  'strategic trade',
#  'gold',
#  'monetary',
#  'gender',
#  'quotas',
#  'protectionist',
#  'stolper samuelson',
#  'lome',
#  'exchange rate regime',
#  'globalization policy',
#  'economic nationalism',
#  'flexible exchange rate',
#  'donor country',
#  'unskilled',
#  'openness',
#  'international downturn',
#  'international capital movement',
#  'international negotiation',
#  'service ratio',
#  'aggregate consumption',
#  'anti dumping',
#  'foreign currency',
#  'intra regional trade',
#  'population migration',
#  'savings investment',
#  'poverty',
#  'currency revaluation',
#  'capital inflow',
#  'long term capital movement',
#  'productivity',
#  'gorman polar',
#  'scale economies',
#  'neoclassical trade models',
#  'usaid',
#  'debt burden',
#  'capial controls',
#  'from trade',
#  'open economy macroeconomics',
#  'guestworker',
#  'open economy macroeconomy',
#  'trade and geography',
#  'member states',
#  'import restricted',
#  'international assistance',
#  'development',
#  'gatt',
#  'net capital outflow',
#  'terrorism',
#  'foreign trade multiplier',
#  'protectionism',
#  'global',
#  'agreement',
#  'sovereign debt',
#  'duty free',
#  'target zone',
#  'import subsidies',
#  'refugee',
#  'dependency theory',
#  'welfare',
#  'wage shares',
#  'north south',
#  'war relations',
#  'integration',
#  'eu',
#  'oligopolistic',
#  'trade',
#  'factor movements',
#  'credit',
#  'lerner',
#  'peace keeping',
#  'world economy',
#  'less developed',
#  'eurocentric',
#  'gains from trade',
#  'global rebalancing',
#  'currency union',
#  'open economy simulation',
#  'global economic crisis',
#  'international migration',
#  'gcc',
#  'samuelson',
#  'oligopolies',
#  'division of labor',
#  'relations',
#  'spot rate',
#  'interest parity',
#  'transmigration',
#  'financial intermediaries',
#  'bank for international settlements',
#  'creditor nation',
#  'colonialism',
#  'imf policies',
#  'globalism',
#  'multinational bargaining',
#  'economic growth',
#  'countries',
#  'export price',
#  'monetary union',
#  'trade balance',
#  'forecasting',
#  'debt',
#  'european economic community',
#  'external debt',
#  'subsidies',
#  'competitiveness',
#  'open economy growth',
#  'macroeconomic issues',
#  'international factor movements',
#  'g-7',
#  'convergence',
#  'drawing rights',
#  'labor migration',
#  'export restrictions',
#  'multilateralism',
#  'foreign investment',
#  'foreign exchange reserves',
#  'cooperation',
#  'tobin tax',
#  'distribution',
#  'world bank',
#  'currency area',
#  'marshall',
#  'transport costs',
#  'international financial forecasting',
#  'program',
#  'wage',
#  'global imbalances',
#  'policy effectiveness',
#  'comparative cost',
#  'trade surplus',
#  'monetary institutions',
#  'international income data',
#  'banking crisis',
#  'reserves',
#  'optimal currency area',
#  'brain drain',
#  'international business',
#  'comecon',
#  'transnational',
#  'remittances',
#  'disarmament',
#  'emigration',
#  'international monetary arrangements',
#  'basel accords',
#  'development policy',
#  'marshall lerner',
#  'export led',
#  'washington consensus',
#  'international financial regulation',
#  'trade statistics',
#  'trading partners',
#  'patriotism',
#  'ecu',
#  'international business cycles',
#  'industrial organization',
#  'tariff',
#  'investment',
#  'balance of payments',
#  'finance',
#  'g-20',
#  'international business cycle forecasting',
#  'capital control',
#  'international industrial order',
#  'import substitution',
#  'efta',
#  'import price',
#  'international contagion',
#  'labor mobility',
#  'interregional trade',
#  'income',
#  'international business trends',
#  'dumping',
#  'conflict resolution',
#  'fifa',
#  'negotiation',
#  'direct investment',
#  'transfer problem',
#  'open economies',
#  'policy convergence',
#  'gravity',
#  'intervention',
#  'macroeconomic interdependence',
#  'lending',
#  'industrial policy',
#  'model',
#  'real exchange rate',
#  'inequality',
#  'free trade',
#  'trade projection',
#  'currency crisis',
#  'arrangements',
#  'apec',
#  'international policy coordination',
#  'financial',
#  'sanctions',
#  'capital mobility',
#  'policy',
#  'big mac parity',
#  'terms of trade',
#  'creditworthiness',
#  'international organization',
#  'country',
#  'new international economic order',
#  'rate of return',
#  'capital flow',
#  'international reserves',
#  'trade policy',
#  'imperialism',
#  'absorptive capacity',
#  'trade volume',
#  'managed trade',
#  'debt rescheduling',
#  'emergency relief',
#  'adjustment programs',
#  'foreign ownership',
#  'foreign assistance',
#  'international conflict',
#  'colony',
#  'rent seeking',
#  'leontief paradox',
#  'financial contagion',
#  'public policy',
#  'intra industry trade',
#  'factor share distribution',
#  'foreign trade',
#  'international financial policy',
#  'mundell fleming',
#  'autarky',
#  'transfer paradox',
#  'postcolonialism',
#  'trade models',
#  'most favored nation',
#  'open economy model',
#  'natural resource security',
#  'fiscal policy',
#  'standard',
#  'trade partners',
#  'fdi',
#  'factor',
#  'current account',
#  'optimal trade policy',
#  'international policy transmission',
#  'pollution haven',
#  'export promoting',
#  'exchange rates',
#  'international debt',
#  'flow',
#  'multinational firm',
#  'united nations',
#  'external supply shocks',
#  'foreign aid',
#  'conflict cooperation',
#  'foreign exchange',
#  'substitution',
#  'multinational corporations',
#  'dual currency',
#  'monopolies',
#  'global outlook',
#  'heckscher ohlin',
#  'foreign direct investment',
#  'stolper',
#  'purchasing power parity',
#  'gains',
#  'liberalization',
#  'reconstruction',
#  'capital flight',
#  'eec',
#  'nafta',
#  'east caribbean central bank',
#  'nontariff barrier',
#  'international economic order',
#  'market structure',
#  'immiserizing growth',
#  'migrant remittances',
#  'conflict',
#  'deficit',
#  'transactions tax',
#  'economic globalization',
#  'immigration']

# %%
class Feature_Kw(BaseEstimator, TransformerMixin):
    def __init__(self, kw, max_len):
        self.kw = kw
        self.max_len = max_len
        pass

    def fit(self, examples, y=None):
        return self

    def transform(self, examples, y=None):
        
        X = np.zeros((len(examples), len(self.kw)))
        
        tmp = []
        first_pass = True
        while self.max_len > 0:
            for i, abstract in enumerate(examples):
                token = word_tokenize(abstract)
                tmp_grams = list(ngrams(token, self.max_len))
                grams = [' '.join(i) for i in tmp_grams]
                for k in self.kw:
                    if first_pass == True:
                        if k in grams:
                            tmp.append(1)
                        else:
                            tmp.append(0)
                            
                        self.max_len -= 1
                    else:
                        if k in grams:
                            ind = self.kw.index(k)
                            tmp[ind] = 1
                            
                        self.max_len -= 1
                            
                first_pass = False
            
            X[i, :] = np.array(tmp)
        
        return X

# %%
pipeline = Pipeline([
        ('features', FeatureUnion([
            ('tfidf', TfidfVectorizer(stop_words='english', lowercase=True)),
            ('keywords', Feature_Kw(kw, max_length))
        ])),
        ('classifier', SGDClassifier(loss='hinge', n_iter=200, penalty='elasticnet'))
    ])

# %%
scores = cross_val_score(pipeline, X_test, y_test, cv=5)

print("Scores: ", scores)
print("Accuracy (mean, std): ", (scores.mean(), scores.std() * 2))
# Out:
# Scores:  [ 0.91791792  0.92092092  0.92242242  0.92338508  0.91783567]
# Accuracy (mean, std):  (0.92049640204407424, 0.0045573927275194617)

# %% [markdown]
# >We develop a ROC curve.

# %%
from sklearn.metrics import roc_curve, auc

# %%
y_score = pipeline.fit(X_train, y_train).decision_function(X_test)

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()

fpr[0], tpr[0], _ = roc_curve(y_test, y_score, pos_label='1')
roc_auc[0] = auc(fpr[0], tpr[0])
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel(), pos_label='1')
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()
lw = 2
plt.plot(fpr[0], tpr[0], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[0])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("F Code Classification")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# >Save our model for later.

# %%
from sklearn.externals import joblib

joblib.dump(pipeline, 'pipeline.pkl')
# Out:
# ['pipeline.pkl']
